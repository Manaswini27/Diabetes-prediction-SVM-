# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json

# Load the .ipynb file
file_path = "/content/Diabetes-Prediction-Using-SVM/diabetes_prediction.ipynb"  # Replace with your actual file path
with open(file_path, 'r') as f:
    notebook_data = json.load(f)

# Extract code cells
code_cells = [cell['source'] for cell in notebook_data['cells'] if cell['cell_type'] == 'code']

# Combine and display the code (optional)
for i, cell_code in enumerate(code_cells, 1):
    print(f"### Code Cell {i} ###\n{''.join(cell_code)}\n")
    # this will output the code so i have manually added to the cells
# Out:
# ### Code Cell 1 ###
# import pandas as pd
# import numpy as np
# from sklearn.preprocessing import StandardScaler #(standardize data to common range)
# from sklearn.model_selection import train_test_split
# from sklearn import svm
# from sklearn.metrics import accuracy_score
#
# ### Code Cell 2 ###
#  # Loading the diabetes dataset to pandas dataframe
# df=pd.read_csv("diabetes.csv")
#
# ### Code Cell 3 ###
# df.head()
#
# ### Code Cell 4 ###
# # statistical measure of data
# df.describe()
#
# ### Code Cell 5 ###
# df["Outcome"].value_counts()
#
# ### Code Cell 6 ###
# # pd.read_csv?
#
# ### Code Cell 7 ###
# df.shape
#
# ### Code Cell 8 ###
# df.groupby("Outcome").mean()
#
# ### Code Cell 9 ###
# # this info is very important for us
# # you can see person having more glucose level,insulin,age is diabetic
#
# ### Code Cell 10 ###
# # all data except labels
# X= df.drop(columns="Outcome",axis=1)
# y=df["Outcome"]
#
# ### Code Cell 11 ###
# print(X)
#
# ### Code Cell 12 ###
# print(y)
#
# ### Code Cell 13 ###
# # for better prediction we will standardize them
# # scaler=StandardScaler()
#
# ### Code Cell 14 ###
# # scaler.fit(X)
#
# ### Code Cell 15 ###
# # standardized_data = scaler.transform(X)
#
# ### Code Cell 16 ###
# # print(standardized_data)
#
# ### Code Cell 17 ###
# # X=standardized_data
# # y=df["Outcome"]
#
# ### Code Cell 18 ###
# # print(X)
# # print(y)
#
# ### Code Cell 19 ###
# X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,stratify=y, random_state=2)
#
# ### Code Cell 20 ###
# # stratify on "Outcome" column to maintain similar proportion of diabetic or non-diabetic
# # random-state is like an index number for partiular splitting of data
#
# ### Code Cell 21 ###
# print(X.shape,X_train.shape,X_test.shape)
#
# ### Code Cell 22 ###
# classifier=svm.SVC(kernel='linear')
#
# ### Code Cell 23 ###
# classifier.fit(X_train,y_train)
#
# ### Code Cell 24 ###
# # accuracy_score of training data
#
# X_train_prediction=classifier.predict(X_train)
# training_data_accuracy_score=accuracy_score(y_train,X_train_prediction)
# print(f"Accuracy Score of training data : {training_data_accuracy_score * 100} %")
#
# ### Code Cell 25 ###
# # accuracy_score of testing data
#
# X_test_prediction=classifier.predict(X_test)
# testing_data_accuracy_score=accuracy_score(y_test,X_test_prediction)
# print(f"Accuracy Score of testing data : {testing_data_accuracy_score * 100} %")
#
# ### Code Cell 26 ###
# import pickle
#
# ### Code Cell 27 ###
# filename="diabetesmodel.sav"
# pickle.dump(classifier,open(filename,'wb'))
#
# ### Code Cell 28 ###
# # loading the saved model
# loaded_model=pickle.load(open("diabetesmodel.sav",'rb'))
#
# ### Code Cell 29 ###
# # 1,85,66,29,0,26.6,0.351,31,0
# # 8,183,64,0,0,23.3,0.672,32,1
# input_data=(1,85,66,29,0,26.6,0.351,31)
#
# # change input_data to numpy array
# inp_data_as_numpy_arr=np.asarray(input_data)
# print(f"1D Data : {inp_data_as_numpy_arr}\n")
#
# # input data reshape because model is expecting 2D array or all data , we'll reshape our 1d data to 2d and feed our model an instance
# inp_data_reshape=inp_data_as_numpy_arr.reshape(1,-1)
# print(f"2D Data : {inp_data_reshape}\n")
#
# # standardize the input data
# # std_data=scaler.transform(inp_data_reshape)
# # print(f"Standardized Data : {std_data}\n")
#
# # prediction
# prediction = loaded_model.predict(inp_data_reshape)
# print(f"Predicted Value: {prediction}")
# if(prediction[0]==0):
#     print("This person is Non-Diabetic")
# else:
#     print("This person is Diabetic")
#
# ### Code Cell 30 ###
#
#
# ### Code Cell 31 ###

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler #(standardize data to common range)
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
 # Loading the diabetes dataset to pandas dataframe
df=pd.read_csv("diabetes.csv")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
df["Outcome"].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
## Code Cell 5 ###
df["Outcome"].value_counts()

### Code Cell 6 ###
# pd.read_csv?

### Code Cell 7 ###
df.shape

### Code Cell 8 ###
df.groupby("Outcome").mean()

### Code Cell 9 ###
# this info is very important for us
# you can see person having more glucose level,insulin,age is diabetic

### Code Cell 10 ###
# all data except labels
X= df.drop(columns="Outcome",axis=1)
y=df["Outcome"]

### Code Cell 11 ###
print(X)

### Code Cell 12 ###
print(y)

### Code Cell 13 ###
# for better prediction we will standardize them
# scaler=StandardScaler()

### Code Cell 14 ###
# scaler.fit(X)

### Code Cell 15 ###
# standardized_data = scaler.transform(X)

### Code Cell 16 ###
# print(standardized_data)

### Code Cell 17 ###
# X=standardized_data
# y=df["Outcome"]

### Code Cell 18 ###
# print(X)
# print(y)

### Code Cell 19 ###
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,stratify=y, random_state=2)

### Code Cell 20 ###
# stratify on "Outcome" column to maintain similar proportion of diabetic or non-diabetic
# random-state is like an index number for partiular splitting of data

### Code Cell 21 ###
print(X.shape,X_train.shape,X_test.shape)

### Code Cell 22 ###
classifier=svm.SVC(kernel='linear')

### Code Cell 23 ###
classifier.fit(X_train,y_train)

### Code Cell 24 ###
# accuracy_score of training data

X_train_prediction=classifier.predict(X_train)
training_data_accuracy_score=accuracy_score(y_train,X_train_prediction)
print(f"Accuracy Score of training data : {training_data_accuracy_score * 100} %")
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   32
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# 763                     0.171   63
# 764                     0.340   27
# 765                     0.245   30
# 766                     0.349   47
# 767                     0.315   23
#
# [768 rows x 8 columns]
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64
# (768, 8) (614, 8) (154, 8)
# Accuracy Score of training data : 78.33876221498372 %

# %%
### Code Cell 25 ###
# accuracy_score of testing data

X_test_prediction=classifier.predict(X_test)
testing_data_accuracy_score=accuracy_score(y_test,X_test_prediction)
print(f"Accuracy Score of testing data : {testing_data_accuracy_score * 100} %")

### Code Cell 26 ###
import pickle

### Code Cell 27 ###
filename="diabetesmodel.sav"
pickle.dump(classifier,open(filename,'wb'))

### Code Cell 28 ###
# loading the saved model
loaded_model=pickle.load(open("diabetesmodel.sav",'rb'))
# Out:
# Accuracy Score of testing data : 77.27272727272727 %

# %%
### Code Cell 29 ###
# 1,85,66,29,0,26.6,0.351,31,0
# 8,183,64,0,0,23.3,0.672,32,1
input_data = (5, 183, 64, 0, 0, 23.3, 0.672, 32)  # Replace this tuple with your values


# change input_data to numpy array
inp_data_as_numpy_arr=np.asarray(input_data)
print(f"1D Data : {inp_data_as_numpy_arr}\n")

# input data reshape because model is expecting 2D array or all data , we'll reshape our 1d data to 2d and feed our model an instance
inp_data_reshape=inp_data_as_numpy_arr.reshape(1,-1)
print(f"2D Data : {inp_data_reshape}\n")

# standardize the input data
# std_data=scaler.transform(inp_data_reshape)
# print(f"Standardized Data : {std_data}\n")

# prediction
prediction = loaded_model.predict(inp_data_reshape)
print(f"Predicted Value: {prediction}")
if(prediction[0]==0):
    print("This person is Non-Diabetic")
else:
    print("This person is Diabetic")
# Out:
# 1D Data : [  5.    183.     64.      0.      0.     23.3     0.672  32.   ]
#
# 2D Data : [[  5.    183.     64.      0.      0.     23.3     0.672  32.   ]]
#
# Predicted Value: [1]
# This person is Diabetic
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
## we are trying to give custom input
##input_data = (1, 90, 70, 35, 0, 33.1, 0.472, 25) basically keep replacing it hinde
